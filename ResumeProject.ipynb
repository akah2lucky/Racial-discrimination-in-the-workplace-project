# %%
# importing a module using python 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading a csv file using pandas
df = pd.read_csv('ResumeNames.csv')
df
# Out:
#       Unnamed: 0     name  gender ethnicity quality call     city  jobs  \
# 0              1  Allison  female      cauc     low   no  chicago     2
# 1              2  Kristen  female      cauc    high   no  chicago     3
# 2              3  Lakisha  female      afam     low   no  chicago     1
# 3              4  Latonya  female      afam    high   no  chicago     4
# 4              5   Carrie  female      cauc    high   no  chicago     3
# ...          ...      ...     ...       ...     ...  ...      ...   ...
# 4865        4866   Tamika  female      afam     low   no   boston     2
# 4866        4867    Ebony  female      afam     low   no   boston     4
# 4867        4868      Jay    male      cauc    high   no   boston     6
# 4868        4869  Latonya  female      afam    high   no   boston     4
# 4869        4870   Laurie  female      cauc     low   no   boston     3
#
#       experience honors  ... minimum equal      wanted requirements reqexp  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'gender', 'ethnicity', 'quality', 'call', 'city',
#        'jobs', 'experience', 'honors', 'volunteer', 'military', 'holes',
#        'school', 'email', 'computer', 'special', 'college', 'minimum', 'equal',
#        'wanted', 'requirements', 'reqexp', 'reqcomm', 'reqeduc', 'reqcomp',
#        'reqorg', 'industry'],
#       dtype='object')

# %%
#unnamed:0 column to  be dropped,because no description
df=df.drop('Unnamed: 0',axis=1)
df
# Out:
#          name  gender ethnicity quality call     city  jobs  experience  \
# 0     Allison  female      cauc     low   no  chicago     2           6
# 1     Kristen  female      cauc    high   no  chicago     3           6
# 2     Lakisha  female      afam     low   no  chicago     1           6
# 3     Latonya  female      afam    high   no  chicago     4           6
# 4      Carrie  female      cauc    high   no  chicago     3          22
# ...       ...     ...       ...     ...  ...      ...   ...         ...
# 4865   Tamika  female      afam     low   no   boston     2           1
# 4866    Ebony  female      afam     low   no   boston     4           6
# 4867      Jay    male      cauc    high   no   boston     6           8
# 4868  Latonya  female      afam    high   no   boston     4           2
# 4869   Laurie  female      cauc     low   no   boston     3           7
#
#      honors volunteer  ... minimum equal      wanted requirements reqexp  \
# ...

# %%
#data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4870 entries, 0 to 4869
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          4870 non-null   object
#  1   gender        4870 non-null   object
#  2   ethnicity     4870 non-null   object
#  3   quality       4870 non-null   object
#  4   call          4870 non-null   object
#  5   city          4870 non-null   object
#  6   jobs          4870 non-null   int64
#  7   experience    4870 non-null   int64
#  8   honors        4870 non-null   object
#  9   volunteer     4870 non-null   object
#  10  military      4870 non-null   object
#  11  holes         4870 non-null   object
#  12  school        4870 non-null   object
#  13  email         4870 non-null   object
#  14  computer      4870 non-null   object
#  15  special       4870 non-null   object
#  16  college       4870 non-null   object
#  17  minimum       4870 non-null   object
# ...

# %%
#check value counts for ethnicity
df['ethnicity'].value_counts()
# Out:
# cauc    2435
# afam    2435
# Name: ethnicity, dtype: int64

# %%
#check value counts for quality of education
df['quality'].value_counts()
# Out:
# high    2446
# low     2424
# Name: quality, dtype: int64

# %%
#check value counts for listed job experience
df['jobs'].value_counts()
# Out:
# 4    1611
# 3    1429
# 2     704
# 5     533
# 6     464
# 1     110
# 7      19
# Name: jobs, dtype: int64

# %%
df.isna().sum()
# Out:
# name            0
# gender          0
# ethnicity       0
# quality         0
# call            0
# city            0
# jobs            0
# experience      0
# honors          0
# volunteer       0
# military        0
# holes           0
# school          0
# email           0
# computer        0
# special         0
# college         0
# minimum         0
# equal           0
# wanted          0
# requirements    0
# reqexp          0
# reqcomm         0
# reqeduc         0
# reqcomp         0
# reqorg          0
# industry        0
# dtype: int64

# %%
sns.scatterplot(data=df,x='minimum',y='experience',hue='ethnicity')
# Out:
# <AxesSubplot:xlabel='minimum', ylabel='experience'>

# %%
df['minimum'].value_counts()
# Out:
# none    2746
# some    1064
# 2        356
# 3        331
# 5        163
# 1        142
# 10        18
# 7         12
# 8         10
# 0.5        8
# 4          8
# 6          8
# 0          4
# Name: minimum, dtype: int64

# %%
df.dtypes
# Out:
# name            object
# gender          object
# ethnicity       object
# quality         object
# call            object
# city            object
# jobs             int64
# experience       int64
# honors          object
# volunteer       object
# military        object
# holes           object
# school          object
# email           object
# computer        object
# special         object
# college         object
# minimum         object
# equal           object
# wanted          object
# requirements    object
# reqexp          object
# reqcomm         object
# reqeduc         object
# reqcomp         object
# reqorg          object
# industry        object
# dtype: object

# %%
wanted=df['wanted'].value_counts()

# %%
wanted.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
industry=df['industry'].value_counts()

# %%
industry.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['requirements']
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 4865    yes
# 4866     no
# 4867     no
# 4868     no
# 4869     no
# Name: requirements, Length: 4870, dtype: object
